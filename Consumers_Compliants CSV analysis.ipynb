# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import matplotlib as mpl

# %% [markdown]
# # python read csv file by 'pandas'

# %%
path1='C:\\Users\\pc\\Desktop\\Consumer_Complaints.csv'
df=pd.read_csv(path1)

# %%
df.head(1000)
# Out:
#     Date received                                            Product  \
# 0      03/12/2014                                           Mortgage
# 1      01/19/2017                                       Student loan
# 2      04/06/2018                        Credit card or prepaid card
# 3      06/08/2014                                        Credit card
# 4      09/13/2014                                    Debt collection
# 5      11/13/2013                                           Mortgage
# 6      06/16/2015                                    Debt collection
# 7      08/22/2018                                           Mortgage
# 8      11/13/2015                                           Mortgage
# 9      10/21/2014                                           Mortgage
# 10     04/14/2017                                           Mortgage
# 11     03/30/2012                                       Student loan
# 12     01/07/2015                                   Credit reporting
# ...

# %%
df.loc[0]
# Out:
# Date received                                                 03/12/2014
# Product                                                         Mortgage
# Sub-product                                               Other mortgage
# Issue                           Loan modification,collection,foreclosure
# Sub-issue                                                            NaN
# Consumer complaint narrative                                         NaN
# Company public response                                              NaN
# Company                                             M&T BANK CORPORATION
# State                                                                 MI
# ZIP code                                                           48382
# Tags                                                                 NaN
# Consumer consent provided?                                           NaN
# Submitted via                                                   Referral
# ...

# %%
df_cd=df[df["Product"]=="Credit card"]

# %%
len(df_cd)
# Out:
# 89190

# %%
df2= df_cd.loc[:,["Product","Company response to consumer"]].copy()
df2.head(100)
# Out:
#           Product     Company response to consumer
# 3     Credit card          Closed with explanation
# 29    Credit card          Closed with explanation
# 55    Credit card          Closed with explanation
# 58    Credit card          Closed with explanation
# 107   Credit card          Closed with explanation
# 127   Credit card      Closed with monetary relief
# 133   Credit card          Closed with explanation
# 134   Credit card      Closed with monetary relief
# 139   Credit card  Closed with non-monetary relief
# 167   Credit card          Closed with explanation
# 172   Credit card      Closed with monetary relief
# 180   Credit card      Closed with monetary relief
# 187   Credit card  Closed with non-monetary relief
# 189   Credit card          Closed with explanation
# 226   Credit card  Closed with non-monetary relief
# 232   Credit card      Closed with monetary relief
# 236   Credit card      Closed with monetary relief
# ...

# %%
df3=df_cd[(df_cd["Submitted via"]=="Web")&(df_cd["Timely response?"]=="Yes")].copy()
df4=df_cd[(df_cd["Submitted via"]=="Web")&(df_cd["Timely response?"]=="No")].copy()
df3.head()
# Out:
#     Date received      Product Sub-product  \
# 3      06/08/2014  Credit card         NaN
# 29     09/17/2014  Credit card         NaN
# 58     04/06/2017  Credit card         NaN
# 107    04/15/2016  Credit card         NaN
# 127    06/28/2013  Credit card         NaN
#
#                                      Issue Sub-issue  \
# 3                               Bankruptcy       NaN
# 29                      Delinquent account       NaN
# 58                               Other fee       NaN
# 107  Identity theft / Fraud / Embezzlement       NaN
# 127                   APR or interest rate       NaN
#
#     Consumer complaint narrative  \
# 3                            NaN
# 29                           NaN
# 58                           NaN
# 107                          NaN
# 127                          NaN
#
#                                Company public response  \
# 3                                                  NaN
# 29                                                 NaN
# ...

# %%
labels="not credict card","not submmited via web","timely response","not timely"
size=[int(len(df)-len(df_cd)),int(len(df_cd)-len(df3)-len(df4)),int(len(df3)),int(len(df4))]

labels2="not submmited via web","timely response","not timely"
size2=[int(len(df_cd)-len(df3)-len(df4)),int(len(df3)),int(len(df4))]
separated=(0,0,0,.2)
separated2=(0,0,.2)
with plt.xkcd():
    plt.subplot(211) 
    plt.pie(size , labels = labels,autopct='%1.1f%%',explode=separated) 
    plt.title("A. the percentage of Credit Card complaints",fontsize=12,loc ='left',bbox=dict(facecolor='none',edgecolor='black', alpha=0.9 ))
    plt.axis('equal')
    
    plt.subplot(212) 
    plt.pie(size2, labels = labels2,autopct='%1.1f%%',explode=separated2) 
    plt.title("B. RELATIONSHIP BETWEEN SUBMMIT METHOD AND RESPONSE TIME in Credit Card complaints",fontsize=12,loc ='left',bbox=dict(facecolor='none',edgecolor='black', alpha=0.9 ))
    plt.axis('equal')

# %%
len(df)
# Out:
# 1143201

# %% [markdown]
# # dealing with missing data (NaN)

# %%
df.isnull()
# Out:
#         Date received Product Sub-product  Issue Sub-issue  \
# 0               False   False       False  False      True
# 1               False   False       False  False     False
# 2               False   False       False  False     False
# 3               False   False        True  False      True
# 4               False   False       False  False     False
# 5               False   False       False  False      True
# 6               False   False       False  False     False
# 7               False   False       False  False      True
# 8               False   False       False  False      True
# 9               False   False       False  False      True
# 10              False   False       False  False      True
# 11              False   False       False  False      True
# 12              False   False        True  False     False
# 13              False   False       False  False      True
# 14              False   False        True  False     False
# ...

# %%
dfnan1=df.fillna(0)  ##fill "NAN" with 0

# %%
dfnan1.head()
# Out:
#   Date received                      Product  \
# 0    03/12/2014                     Mortgage
# 1    01/19/2017                 Student loan
# 2    04/06/2018  Credit card or prepaid card
# 3    06/08/2014                  Credit card
# 4    09/13/2014              Debt collection
#
#                                   Sub-product  \
# 0                              Other mortgage
# 1              Federal student loan servicing
# 2  General-purpose credit card or charge card
# 3                                           0
# 4                                 Credit card
#
#                                       Issue  \
# 0  Loan modification,collection,foreclosure
# 1        Dealing with my lender or servicer
# 2        Other features, terms, or problems
# 3                                Bankruptcy
# 4                     Communication tactics
#
#                                 Sub-issue  \
# 0                                       0
# 1  Received bad information about my loan
# ...

# %%
dfdropna=df.dropna()

# %%
df.dropna(how="any") ##when row exixts "NAN" than delet
# Out:
#         Date received          Product                            Sub-product  \
# 936        10/20/2015  Debt collection                               Mortgage
# 2370       12/01/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 3523       03/21/2017  Debt collection  Other (i.e. phone, health club, etc.)
# 8469       03/01/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 13229      06/01/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 14824      06/02/2016  Debt collection                                Medical
# 16762      02/09/2017  Debt collection  Other (i.e. phone, health club, etc.)
# 17212      02/01/2016  Debt collection                          I do not know
# 18339      08/10/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 19297      04/04/2017  Debt collection  Other (i.e. phone, health club, etc.)
# 20192      07/17/2015  Debt collection  Other (i.e. phone, health club, etc.)
# ...

# %%
df.dropna(how="any",axis=1)  ##when column exixts "NAN" than delet
# Out:
#         Date received                                            Product  \
# 0          03/12/2014                                           Mortgage
# 1          01/19/2017                                       Student loan
# 2          04/06/2018                        Credit card or prepaid card
# 3          06/08/2014                                        Credit card
# 4          09/13/2014                                    Debt collection
# 5          11/13/2013                                           Mortgage
# 6          06/16/2015                                    Debt collection
# 7          08/22/2018                                           Mortgage
# 8          11/13/2015                                           Mortgage
# 9          10/21/2014                                           Mortgage
# 10         04/14/2017                                           Mortgage
# 11         03/30/2012                                       Student loan
# ...

# %%
df.dropna(thresh=3)# 每行至少3個非空值才保留
# Out:
#         Date received                                            Product  \
# 0          03/12/2014                                           Mortgage
# 1          01/19/2017                                       Student loan
# 2          04/06/2018                        Credit card or prepaid card
# 3          06/08/2014                                        Credit card
# 4          09/13/2014                                    Debt collection
# 5          11/13/2013                                           Mortgage
# 6          06/16/2015                                    Debt collection
# 7          08/22/2018                                           Mortgage
# 8          11/13/2015                                           Mortgage
# 9          10/21/2014                                           Mortgage
# 10         04/14/2017                                           Mortgage
# 11         03/30/2012                                       Student loan
# ...

# %%
print(len(df.dropna(thresh=15)),len(df))
# Out:
# 462918 1143201

# %% [markdown]
# # Data analysis

# %%
dfnan1.head()
# Out:
#   Date received                      Product  \
# 0    03/12/2014                     Mortgage
# 1    01/19/2017                 Student loan
# 2    04/06/2018  Credit card or prepaid card
# 3    06/08/2014                  Credit card
# 4    09/13/2014              Debt collection
#
#                                   Sub-product  \
# 0                              Other mortgage
# 1              Federal student loan servicing
# 2  General-purpose credit card or charge card
# 3                                           0
# 4                                 Credit card
#
#                                       Issue  \
# 0  Loan modification,collection,foreclosure
# 1        Dealing with my lender or servicer
# 2        Other features, terms, or problems
# 3                                Bankruptcy
# 4                     Communication tactics
#
#                                 Sub-issue  \
# 0                                       0
# 1  Received bad information about my loan
# ...

# %%
dfnan1=dfnan1.replace("Yes",1).replace("No",0)
dfnan1.head()
# Out:
#   Date received                      Product  \
# 0    03/12/2014                     Mortgage
# 1    01/19/2017                 Student loan
# 2    04/06/2018  Credit card or prepaid card
# 3    06/08/2014                  Credit card
# 4    09/13/2014              Debt collection
#
#                                   Sub-product  \
# 0                              Other mortgage
# 1              Federal student loan servicing
# 2  General-purpose credit card or charge card
# 3                                           0
# 4                                 Credit card
#
#                                       Issue  \
# 0  Loan modification,collection,foreclosure
# 1        Dealing with my lender or servicer
# 2        Other features, terms, or problems
# 3                                Bankruptcy
# 4                     Communication tactics
#
#                                 Sub-issue  \
# 0                                       0
# 1  Received bad information about my loan
# ...

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                                         Company  \
# 0                          M&T BANK CORPORATION
# 1                       Navient Solutions, LLC.
# 2             CAPITAL ONE FINANCIAL CORPORATION
# 3                      AMERICAN EXPRESS COMPANY
# 4                                CITIBANK, N.A.
# 5                                  U.S. BANCORP
# 6                   California Accounts Service
# 7                              BB&T CORPORATION
# 8                            Aldridge Pite, LLP
# 9                      OCWEN LOAN SERVICING LLC
# 10                     Shellpoint Partners, LLC
# 11             Student Loan Finance Corporation
# 12          Experian Information Solutions Inc.
# 13               CITIZENS FINANCIAL GROUP, INC.
# 14          Experian Information Solutions Inc.
# 15                                EQUIFAX, INC.
# 16          Experian Information Solutions Inc.
# 17                                 U.S. BANCORP
# ...

# %%
x=dfnan1["Consumer disputed?"][400:500]
y=dfnan1["Timely response?"][400:500]
z=(dfnan1["Consumer disputed?"][400:500]&dfnan1["Timely response?"][400:500])
plt.subplot(221)
plt.plot(x)

plt.subplot(222)
plt.plot(y)

plt.subplot(223)
plt.plot(z)
